# %% [markdown]
# - Install **lxde, chromium, firefox-esr**
# sudo apt install lxde chromium firefox-esr

# %% [markdown]
# # Install Chrome driver
# - Upload chrome driver linux 64x zip file to jupyter
# - **echo $PATH**로 경로 확인
# - unzip chrome~
#   (If unzip doesn't exist, sudo apt install unzip)
# - sudo mv chromedriver /usr/local/bin/

# %% [markdown]
# # Install Firefox driver
# - Upload geckodriver tar file to jupyter
# - tar xvzf geck~~.tar.gz
# - sudo mv geckodriver /usr/local/bin/

# %% [markdown]
# # CSS
# - Cascading Style Sheets
# - Website의 style을 결정
# - 문서의 context or text는 HTML에서 제공
# - Ex. 색깔, 위치, 글자크기 등등
# - Mobile version의 website를 만들기 위해 사용
#
# ![image.png](data:image/png;base64,...)
#
# Reference:
# https://blog.wishket.com/css-vs-html-vs-%EC%9E%90%EB%B0%94%EC%8A%A4%ED%81%AC%EB%A6%BD%ED%8A%B8-%EB%8C%80%EC%B2%B4-%EB%AD%90%EA%B0%80-%EB%8B%A4%EB%A5%B8%EA%B1%B8%EA%B9%8C/

# %% [markdown]
# # Javascript
# - 동적인 HTML내에서 동적인 요소를 이용하여 HTML내의 값을 실시간으로 변화 할 수 있게 해준다.
# - Ex. 마우스 위치에 따른 특정 구역의 색깔 변화 등
# - < SCRIPT >...< /SCRIPT >
# - .js

# %% [markdown]
# # AJAX
# - HTML내의 일부분을 실시간으로 server와 communication할 수 있게 해줌
# - Ex. 연관검색어 표출

# %% [markdown]
# # Cookie
# - Web server가 user를 구분하기 위한 용도로 사용
# - 구분을 위한 특별한 key value를 user computer에 저장하여 server와 소통할 때 마다 해당 key value를 사용
# - 로그인 정보를 담은 cookie 이용

# %% [markdown]
# # HTTPS
# - Web server와 client(browser)간 통신 내용을 암호화
#
# ![image.png](data:image/png;base64,...)
#
# Reference:
# https://www.cloudflare.com/ko-kr/ssl/
#
# # 인정서
# - 인증서 내에 암호화에 사용할 공개키가 담겨있음
# - 공개키의 진위성을 확인하기 위해 공인기관이 발급한 인증서를 사용
# - 인증서의 진위성 확인의 중요도 여부 결정 가능 (인증서 정보가 올바르지 않을 경우 해결하는 방법)

# %%
python3

from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys

opt = Options()
opt.headless = True
driver = webdriver.Firefox(options = opt)
driver.get('https://google.com')

# 검색창 사용하기
driver.find_element()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a103b82059d0> in <module>()
# ----> 1 python3
#       2
#       3 from selenium import webdriver
#       4 from selenium.webdriver.firefox.options import Options
#       5
#
# NameError: name 'python3' is not defined

# %% [markdown]
# # 공공데이터 포털 사이트에서 표준데이터셋 crawling하기

# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

opt = Options()
opt.headless = True

driver = webdriver.Firefox(options = opt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-17196b77af5f> in <module>()
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.firefox.options import Options
#       3 from selenium.webdriver.common.keys import Keys
#       4 from selenium.webdriver.common.by import By
#       5
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 네이버 운세 자동 검색하기

# %%
driver.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%9A%B4%EC%84%B8')
# print(driver.title)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
